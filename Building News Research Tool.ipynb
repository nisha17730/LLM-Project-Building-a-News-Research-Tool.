# %% [markdown]
# #### Task 1.1: Install Required Libraries

# %%
from newsapi import NewsApiClient

# %%
# Initialize the NewsAPI client with your API key
newsapi = NewsApiClient(api_key='21f98b8589d74677ae9d6dd2d3216cf9')

# Define a function to get news articles based on a query
def get_news_articles(query):
    articles = newsapi.get_everything(q=query, language='en', sort_by='relevancy')
    return articles['articles']

# Example usage
query = 'technology'
articles = get_news_articles(query)
for article in articles:
    print(f"Title: {article['title']}")
    print(f"Description: {article['description']}\n")
# Out:
# Title: This Ancient Technology Is Helping Millions Stay Cool
# Description: Cheap, low-energy evaporative cooling devices are keeping water, food, people, and even whole buildings cool across India.
#
# Title: Go Read This: The Verge’s favorite reads from all over the web
# Description: These are the best reads on the web about technology, science, entertainment, gaming, and more, curated by the staff of The Verge.
#
# Title: Netflix’s King of Collectibles Has Become a Pop Culture Dreamland
# Description: Netflix's auction reality show has grown from sports to comics, Pokémon, technology, video games, and more.
#
# Title: Steel talks for Starmer's first Wales visit as PM
# Description: New Labour government says a better deal is available, but warns fresher technology would cut jobs.
#
# Title: [Removed]
# Description: [Removed]
#
# Title: UFOs: From psychology to air traffic, are we closer than ever to an answer?
# Description: Why modern technology puts us in a stronger position than ever to work out what's going on in the skies above us.
#
# Title: Neo-Nazis Are All-In On AI
# Description: Extremists are developing their own hateful AIs to supercharge radicalization and fundraising—and are now using the tech to make weapon blueprints and bombs. And it’s going to get worse.
#
# Title: Nokia just made the first phone call using 3D spatial audio
# Description: Nokia just announced that it has made the first-ever audio and video call using 3D spatial audio
# . This is actually a big deal, as all phone calls currently made over a cellular network are monophonic, so there’s no possibility for spatial audio.
# This call, …
#
# Title: Elon Musk drops lawsuit against OpenAI
# Description: Elon Musk was suing ChatGPT maker OpenAI and its CEO, Sam Altman, for a breach of contract, but now the lawsuit has been dropped.
#
# Title: ‘Robot pill’ technology reaches clinical trial stage
# Description: A cutting-edge development from Endiatx, a pioneering medical technology company, is aiming to bring a ‘robot pill’ to the market.… Continue reading ‘Robot pill’ technology reaches clinical trial stage
# The post ‘Robot pill’ technology reaches clinical trial s…
#
# Title: AI Turns Classic Memes Into Hideously Animated Garbage
# Description: Have you ever wondered what your favorite memes might look like if they were animated? Well, wonder no longer. Thanks to advancements in artificial intelligence technology, you can now see those static images come to life. And they look like absolute dogshit.…
#
# Title: May 'AI' Take Your Order? McDonald's Says Not Yet
# Description: McDonald’s is ending a two-year-old partnership with IBM to test AI’s ability to replace drive-thru workers at more than 100 restaurants, according to Restaurant Business. The world’s largest fast-food company is reportedly pulling the technology later in Jul…
#
# Title: Sony Bravia 7 Review: A Solid Choice So Long as You Don't Mind Following the TV's Lead
# Description: Sony is pushing its mini-LED TVs hard, harder than one might expect when it has its Bravia 8 OLED TV up for sale simultaneously with last year’s A95L QD-OLED. Sony positioned that ultimate high-end OLED in the same flagship tier alongside the Bravia 9 mini-LE…
#
# Title: 'I’m One Tap Away From Publishing Your Nudes': 12 Horror Stories About Extortion Attempts on Grindr
# Description: Technology has pushed the world of dating into our phones, those same devices that allow us to take photos and videos we may not want the rest of the world to see. And that tectonic shift in culture has made it much easier to run anonymous extortion scams, wh…
#
# Title: The surprisingly not so doomed effort to force US drivers to stop speeding
# Description: Intelligent speed assistance, which prevents drivers from speeding, is gaining public acceptance, according to a surprising new survey.
#
# Title: [Removed]
# Description: [Removed]
#
# Title: Europe Scrambles for Relevance in the Age of AI
# Description: With chatbot and AI development largely coming from the US, some EU entrepreneurs and politicians say local champions are needed to prevent a cultural flattening.
#
# Title: Japan’s government says goodbye to floppy disks
# Description: Floppy disks may seem like a relic from an ancient time of computers but there are still places and even governments in the world that still use them to run its most basic functions. Japan is no longer one of those countries.
# Japan’s Digital Agency announced …
#
# Title: Paramount and Skydance will merge to create new tech-media giant
# Description: David Ellison, the new chief executive of Paramount, has big plans for the media giant and wants to turn it into a "media and technology" company, according to the Financial Times. Ellison is taking over as Paramount's boss after his production studio, Skydan…
#
# Title: Trial Production of Apple's Next-Gen Chip Technology to Begin Next Week
# Description: Apple chipmaker TSMC will begin test production of 2nm chips next week ahead of plans to bring the technology to Apple silicon next year, ET News reports.
#
#
#
#
#
# The trial production run will occur at TSMC's Baoshan plant in northern Taiwan. Equipment designed …
#
# Title: [Removed]
# Description: [Removed]
#
# Title: Our 2024 Environmental Report
# Description: Our 2024 Environmental Report looks at our use of technology to drive environmental change and operate our business sustainably.
#
# Title: Amazon-Powered AI Cameras Used to Detect Emotions of Unwitting UK Train Passengers
# Description: CCTV cameras and AI are being combined to monitor crowds, detect bike thefts, and spot trespassers.
#
# Title: Musk withdraws his breach of contract lawsuit against OpenAI
# Description: Elon Musk dropped a lawsuit against OpenAI one day before a judge in California state court was set to hear OpenAI’s request for dismissal. Musk’s suit, which was filed in February, had accused OpenAI co-founders Sam Altman and Greg Brockman of violating the …
#
# Title: Onehouse secures $35M to advance open data lakehouse technology
# Description: Onehouse is continuing to build out open source Apache Hudi data lake technology, data lake table format interoperability with Apache XTable, alongside the company’s own Universal Data Lakehouse.
#
# Title: [Removed]
# Description: [Removed]
#
# Title: Japan is bracing for rage against the vending machine
# Description: Japan still loves cash and vending machines, but new banknotes containing hologram technology won't work in many machines without upgrades.
#
# Title: Nintendo Has No Plans to Use Generative AI in Its Games, Company President Says
# Description: Mario and Luigi aren't jumping on the AI train. From a report: In a recent Q&A with investors, Nintendo President Shuntaro Furukawa addressed the issue. Though he said generative AI can be creative, Furukawa told his audience that the company isn't planning t…
#
# Title: Japan Achieves 402 TB/s Data Rate - Using Current Fiber Technology
# Description: Tom's Hardware reports that Japan's National Institute of Information and Communications Technology (working with the Aston Institute of Photonic Technologies and Nokia Bell) set a 402 terabits per second data transfer record — over commercially available opt…
#
# Title: Ground robots may be the 'next game-changer technology' of the war, senior Ukrainian official says
# Description: Ukraine is looking to build a fleet of ground robots for assault, minelaying, and logistics missions, Mykhailo Fedorov told Business Insider.
#
# Title: Mark Zuckerberg is 'almost ready' to reveal a prototype that left early testers 'giddy'
# Description: Meta's CTO previously said it might be "the most advanced piece of technology on the planet in its domain."
#
# Title: Flight-free travel business Byway raises $6 million to improve AI usage and expand the technology
# Description: A travel business that deploys AI software to help people book package vacations is announcing the close of an oversubscribed… Continue reading Flight-free travel business Byway raises $6 million to improve AI usage and expand the technology
# The post Flight-f…
#
# Title: North Korea's Kim Jong Un could get his hands on some worrying military tech in exchange for throwing Russia a war lifeline
# Description: As Putin and Kim grow closer, there's the possibility that North Korea could get its hands on winning weapons technology.
#
# Title: Activists Disrupt Amazon Conference Over $1.2 Billion Contract With Israel
# Description: Members of the activist group No Tech for Apartheid interrupted a senior Amazon executive's speech at a conference in Washington, DC, on Wednesday over the company's Project Nimbus cloud contract.
#
# Title: What is the polling day weather forecast?
# Description: Alexandra Humphreys has Thursday's weather forecast for across the UK.
#
# Title: When you can hear every word, thank the sound mixers
# Description: They sit behind a console that looks like the bridge of a spaceship and use complicated technology to bring words from the actors mouth to the audience's ears.
#
# Title: The Pope has quickly become one of AI's biggest skeptics
# Description: Pope Francis warned G7 Summit leaders about the dangers of AI to human dignity, urging them to stay in control of the technology.
#
# Title: A Chinese firm's answer to SpaceX's Falcon 9 blew up in a giant fireball after it accidentally launched during a test
# Description: Tianbing Aerospace Technology said it was testing its rocket engine when the Tianlong-3 left the launchpad due to a "structural failure."
#
# Title: China wants a fleet of aircraft carriers for pride and power, and it's building it at a breakneck pace
# Description: China is rushing to build a fleet of aircraft carriers and making major technology jumps. It sees deep value in these powerful assets.
#
# Title: Apple is the first tech giant to get AI right
# Description: Unlike Google and Microsoft, Apple is using AI to do what the technology has proved it can do rather than unreliable features.
#
# Title: US Bans Kaspersky Software
# Description: Using a Trump-era authority, the US Commerce Department has banned the sale of Kaspersky’s antivirus tools to new customers in the US, citing alleged threats to national security.
#
# Title: The Mystery of AI Gunshot-Detection Accuracy Is Finally Unraveling
# Description: How accurate are gunshot detection systems, really? For years, it's been a secret, but new reports from San Jose and NYC show these systems have operated well below their advertised accuracy rates.
#
# Title: Elon Musk hints that his next move could be making an X phone
# Description: Elon Musk earlier said he'd ban Apple devices from his companies if Apple integrates OpenAI's technology into its systems as it said it would at WWDC.
#
# Title: Business Insider's most innovative CMOs of 2024
# Description: Business Insider's annual list of the "Most Innovative CMOs" spotlights marketers who are rising to challenges while also using new technology, such as generative AI.
#
# Title: [Removed]
# Description: [Removed]
#
# Title: Reimagining the Travel Experience With Biophilia in Singapore’s Changi Airport
# Description: BOIFFILS Architectures’ redesign of Changi Airport’s Terminal 2 blends biophilic elements and technology to create a serene, nature-inspired travel experience prioritizing passenger comfort.
#
# Title: [Removed]
# Description: [Removed]
#
# Title: DHS rolls out new technology for firefighters
# Description: The technology would allow for firefighters to see through smoke.
#
# Title: This is Big Tech’s playbook for swallowing the AI industry
# Description: Amazon has replicated an antitrust-avoidance playbook pioneered by Microsoft with its hiring of most of the team behind buzzy AI startup Adept.
#
# Title: NFC Forum wants to bundle age verification and payment receipts in tap-to-pay
# Description: The NFC Forum, the non-profit org made up of big tech companies promoting the NFC standard, envisions a future wherein one tap is all you need for multiple actions at once. With a single tap, for instance, you could pay for your purchase, get points on your r…
#
# Title: At least 7 stars in our galaxy have the potential to harbor advanced alien technology, researchers find
# Description: After surveying 5 million stars throughout our galaxy, researchers identified seven that may host Dyson spheres: super-advanced alien megastructures.
#
# Title: Two Hearts Beat Beneath the Plug-in Hybrid Lamborghini Urus SE
# Description: Nobody buys a Lamborghini for fuel efficiency or lower emissions, but the newly refreshed plug-in hybrid Urus SE goes faster and is further enhanced by battery technology.
#
# Title: Company develops window wall technology that can produce solar energy: 'An innovation breakthrough'
# Description: None
#
# Title: Nvidia overtakes Microsoft as the world’s most valuable company
# Description: Nvidia’s market cap closed on June 18th at $3.335 trillion, riding an AI boom powered by the company’s GPUs pushing it past Apple, Google, and Microsoft.
#
# Title: Clicks launches physical keyboard case for iPhone at Best Buy
# Description: Clicks Technology today announced its teaming up with Best Buy to bring the popular Clicks Keyboard for iPhone to U.S. customers
#
# Title: US proposes rules to stop Americans from investing in Chinese technology with military uses
# Description: The Treasury Department on Friday fleshed out a proposed rule that would restrict and monitor U.S. investments in China for artificial intelligence, computer...
#
# Title: Signature Kitchen Suite’s Gourmet AI™ Camera Is Smart Enough to Answer, “What’s for Dinner?”
# Description: Signature Kitchen Suite’s new Transitional Series Ovens with Gourmet AI Camera pair handsome contemporary design details with intelligent technology to make cooking at home smarter, more efficient, and incredibly user-friendly.
#
# Title: Customer-Centric Marketing for Technology Vendors
# Description: In today’s fast-paced, highly competitive market, technology vendors often struggle to connect with their customers on a meaningful level. Traditional marketing approaches, which focus on pushing products and services to a broad audience, are no longer effect…
#
# Title: Huawei exec rejects idea that advanced chip shortage will hamper China's AI ambitions
# Description: A senior executive at Chinese technology giant Huawei on Thursday dismissed the idea that a shortage of the most advanced artificial intelligence chips will ...
#
# Title: The Oura Ring is about to face its biggest challenge yet: a fair fight
# Description: Oura has been reigning over the smart ring industry for over a decade now, bringing an advanced, research-grade sensor to the Oura Ring. It now faces a new challenge: competing with a company known for more than just its wearable technology—Samsung.
#
# Title: What’s Eating the Economy?
# Description: Are technology and monopolies to blame for American economic unease?
#
# Title: Detroit Paying $300K to Man Wrongly Accused of Theft, Making Changes to Facial Technology Usage
# Description: The city of Detroit has agreed to pay $300,000 to a man who was wrongly accused of shoplifting.
#
# Title: I Was Wrongfully Arrested Because of Facial Recognition Technology. It Shouldn’t Happen to Anyone Else
# Description: "What the Detroit Police Department made me endure changed my life forever," writes Robert Williams.
#
# Title: This new technology fixes the biggest problem with modern GPUs
# Description: Using their optimized Compute Express Link or CXL, Panmnesia is working on a solution to expand memory capacity for GPUs and AI accelerators.
#
# Title: British Trains To (Maybe) Make Way For Steam Once More
# Description: There’s nothing more guaranteed to excite a grizzled old railway enthusiast than the sight of a steam locomotive. The original main-line rail propulsion technology still clings on in a few …read more
#
# Title: Major record labels sue AI company behind ‘BBL Drizzy’
# Description: Music industry players including Sony Music Entertainment, Universal Music Group, and Warner Records say Suno and Udio stole protected works when training models.
#
# Title: Meta says European regulators are ruining its AI bot
# Description: Meta said Ireland’s Data Protection Commission asked it to delay training LLMs on public user information.
#
# Title: Tim Cook is ‘not 100 percent’ sure Apple can stop AI hallucinations
# Description: In an interview with The Washington Post, Apple CEO Tim Cook says he’s not 100 percent confident that its new Apple Intelligence system won’t hallucinate.
#
# Title: Huawei Technologies sells Aito electric vehicle trademark to partner for US$350 million
# Description: Huawei Technologies is selling the trademark of electric vehicle (EV) brand Aito to its Chinese carmaking partner Seres, as the Shenzhen-based technology...
#
# Title: AI companies need to get society's input as they build out the technology, OpenAI CEO Sam Altman and Airbnb CEO Brian Chesky say
# Description: OpenAI CEO Sam Altman and Airbnb CEO Brian Chesky said tech companies should be transparent with people as they develop artificial intelligence.
#
# Title: How UFL technology can help the NFL: Three innovations that might make the leap
# Description: The NFL already adopted the XFL's kickoff structure, and some of the UFL's technological advances could be next on the NFL's plate.
#
# Title: US Bank has used AI for fraud detection as well as brand campaigns, but CMO Michael Lacorazza says the potential of the technology is yet to be fully understood
# Description: US Bank has used AI for fraud detection as well as brand campaigns, but CMO Michael Lacorazza says the potential of the technology is yet to be fully understood  He spoke to Business Insider at the Cannes Lions 2024 International Festival of Creativity.
#
# Title: A breakthrough technology could make CPUs 100x faster
# Description: Flow Computing claims that its parallel processing unit (PPU) could boost the performance of any CPU by up to 100 times.
#
# Title: Build Your Own Core Rope Memory Module?
# Description: [Luizão] wanted to create some hardware to honour the memory of the technology used to put man on the moon and chose the literal core of the project, that of the hardware used to store the software…
#
# Title: PCB Design Review: A 5V UPS With LTC4040
# Description: Do you have a 5 V device you want to run 24/7, no matter whether you have electricity? Not to worry – Linear Technology has made a perfect IC for you, the LTC4040; with the perfect assortment…
#
# Title: $3 Smartwatch Can Run Python
# Description: [Poking Technology] doesn’t think much of his new smartwatch. It is, by his admission, the cheapest possible smartwatch, coming in at about $3. It has very few useful features but he has figu…
#
# Title: Magic and wonder in the age of AI | David Kwong
# Description: With AI everywhere you look, you may think you've seen it all. Magician David Kwong suggests otherwise, proposing advancements in technology actually increase opportunities for wonder. In an entertaining performance, he invites an audience member on stage to …
#
# Title: Detecting defects in tomorrow's technology
# Description: New research offers an enhanced understanding of common defects in transition-metal dichalcogenides (TMDs) -- a potential replacement for silicon in computer chips -- and lays the foundation for etching smaller features.
#
# Title: TNW Podcast: From satellite tracking and space regulation to multimodal AI, and more
# Description: Welcome to the new episode of the TNW Podcast — the show where we discuss the latest developments in the European technology ecosystem and feature interviews with some of the most interesting people in the industry. In today’s episode, we’re featuring two int…
#
# Title: Waymo's Autonomous Ride-Hailing Service Now Available To All In San Francisco
# Description: An anonymous reader quotes a report from Reuters: Alphabet's Waymo said on Tuesday its autonomous ride-hailing service, Waymo One, is now available to everyone in San Francisco, nearly four years after a similar move in Phoenix, Arizona. Driverless vehicles a…
#
# Title: Logitech G launches a new $80 gaming mouse
# Description: Logitech G has a new toy for gamers to try out. The brand — which is the gaming arm of Logitech — has released the G309 LIGHTSPEED Wireless Gaming Mouse for $80 in black and white. The mouse is Powerplay compatible, meaning you can use it without an AA batter…
#
# Title: Black Semiconductor raises €254.4M for graphene-based chips in boost for European sector
# Description: Amid a global race for semiconductor leadership, an Aachen-based startup has raised €254.4mn for its chip technology in a big boost for the German as well as the European semiconductor sector. Brothers Daniel and Sebastian Schall launched Black Semiconductor …
#
# Title: Google Loses Bid To End US Antitrust Case Over Digital Advertising
# Description: An anonymous reader quotes a report from Reuters: Alphabet's Google must face trial on U.S. antitrust enforcers' claim that the internet search juggernaut illegally dominates the online advertising technology market, a federal judge ruled on Friday. U.S. Dist…
#
# Title: Europe is pouring public funds into quantum tech startups, report says
# Description: A report published today by McKinsey on the state of the global quantum tech sector has found that Europe is spending more and more in public funding on technologies such as quantum computers, quantum sensors, and quantum communications.  Quantum technology i…
#
# Title: Scientists make significant breakthrough in microchip technology that could forever change our electronics: 'It can open up a new realm'
# Description: None
#
# Title: ASUS' ZenScreen Smart 27-inch monitor is its first with Google TV
# Description: ASUS has been busy at Computex 2024 this year, announcing not only the ROG Ally X gaming handheld but a bunch of new laptops. Now, the company has moved on to monitors, unveiling several interesting entertainment and content creation models, including its fir…
#
# Title: Softbank unveils plans to cancel out angry customer emotions using AI
# Description: Real-time voice modification tech seeks to reduce stress in Japanese call center staff.
#
# Title: Let's take your Windows PC's security to the next level with these simple steps
# Description: Technology wizard Kurt "CyberGuy" Knutsson explores some of the more obscure alternative security features to lock down your Windows PC.
#
# Title: You see this beautiful D&D terrain? It was made with Polish space magic.
# Description: Archon Studios’ Prismacast, a proprietary new painting technology, has even the experts confused. Your first look at this bewildering Polish space magic in play.
#
# Title: Tesla Shareholders Approve Elon Musk's Big Payday
# Description: Elon Musk will pocket $56 billion after Tesla shareholders made a show of support for his leadership.
#
# Title: SCOTUS Rules That US Government Can Continue Talking to Social Media Companies
# Description: The Supreme Court ruling overturns an earlier injunction that prevented platforms from communicating with the government for more than a year.
#
# Title: Red Tape Is Making Hospital Ransomware Attacks Worse
# Description: With cyberattacks increasingly targeting health care providers, an arduous bureaucratic process meant to address legal risk is keeping hospitals offline longer, potentially risking lives.
#
# Title: There's an AI Candidate Running for Parliament in the UK
# Description: If it wins, “AI Steve” will be represented by businessman Steve Endacott in Parliament. Endacott says he'll merely be a conduit, and the AI will make the policy decisions.
#
# Title: Amazon is reportedly working on a new AI chatbot
# Description: Amazon is allegedly working on a new chatbot codenamed "Metis," Business Insider reports, citing an internal document and unnamed sources familiar with the project. It would be powered by a new AI model, Olympus, rather than Amazon's previously released Titan…
#
# Title: TDK claims insane energy density in solid state battery breakthrough
# Description: Apple supplier says new tech has 100 times the capacity of its current batteries.
#
# Title: What is Luma AI’s Dream Machine? Why fans are flocking to video generator
# Description: Luma Labs, the AI company known for creating the Genie generative 3D model, has now ventured into AI-powered video technology… Continue reading What is Luma AI’s Dream Machine? Why fans are flocking to video generator
# The post What is Luma AI’s Dream Machine?…
#
# Title: Can AI have a place in comedy? Comedians put it to the test
# Description: With artificial intelligence being used in numerous industries worldwide, comedians have wondered how the technology may affect their careers. Can… Continue reading Can AI have a place in comedy? Comedians put it to the test
# The post Can AI have a place in co…
#
# Title: MGM-owned LeoVegas secures deal to acquire Tipico US sportsbook
# Description: LeoVegas has secured a deal to acquire Tipico Group’s US sportsbook interests, as well as its online casino technology system.… Continue reading MGM-owned LeoVegas secures deal to acquire Tipico US sportsbook
# The post MGM-owned LeoVegas secures deal to acquir…
#
# Title: Report: Apple isn’t paying OpenAI for ChatGPT integration into OSes
# Description: Apple thinks pushing OpenAI’s brand to hundreds of millions is worth more than money.
#
# Title: New extremely fast carbon storage technology
# Description: A new way to store carbon captured from the atmosphere works much faster than current methods without the harmful chemical accelerants they require.
